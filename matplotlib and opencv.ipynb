# %% [markdown]
# ### how to used matplotlib and opencv

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img=cv2.imread('C:/Users/user/Pictures/123.jpg')

# %%
img
# Out:
# array([[[230, 232, 233],
#         [230, 232, 233],
#         [230, 232, 233],
#         ...,
#         [230, 232, 233],
#         [230, 232, 233],
#         [230, 232, 233]],
#
#        [[230, 232, 233],
#         [230, 232, 233],
#         [230, 232, 233],
#         ...,
#         [230, 232, 233],
#         [230, 232, 233],
#         [230, 232, 233]],
#
#        [[230, 232, 233],
#         [230, 232, 233],
#         [230, 232, 233],
#         ...,
#         [230, 232, 233],
#         [230, 232, 233],
#         [230, 232, 233]],
#
#        ...,
#
#        [[ 21, 136,  97],
#         [ 28, 137,  99],
#         [ 16, 110,  75],
#         ...,
#         [ 15, 157, 112],
#         [ 15, 157, 112],
#         [ 14, 158, 110]],
#
#        [[ 18, 148, 107],
#         [ 29, 152, 112],
#         [ 26, 135,  97],
#         ...,
#         [ 15, 157, 112],
#         [ 14, 157, 112],
#         [ 14, 158, 110]],
#
#        [[ 10, 151, 108],
#         [ 19, 153, 111],
#         [ 25, 148, 108],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (399, 715, 3)

# %%
plt.imshow(img)

# %%
img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img2
# Out:
# array([[[233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230],
#         ...,
#         [233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230]],
#
#        [[233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230],
#         ...,
#         [233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230]],
#
#        [[233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230],
#         ...,
#         [233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230]],
#
#        ...,
#
#        [[ 97, 136,  21],
#         [ 99, 137,  28],
#         [ 75, 110,  16],
#         ...,
#         [112, 157,  15],
#         [112, 157,  15],
#         [110, 158,  14]],
#
#        [[107, 148,  18],
#         [112, 152,  29],
#         [ 97, 135,  26],
#         ...,
#         [112, 157,  15],
#         [112, 157,  14],
#         [110, 158,  14]],
#
#        [[108, 151,  10],
#         [111, 153,  19],
#         [108, 148,  25],
# ...

# %%
plt.imshow(img2)

# %% [markdown]
# ## Grayscale Image using Matplotlib & OpenCV P.2

# %%
img_gray=cv2.imread('C:/Users/user/Pictures/123.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (399, 715)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img_gray.min()
# Out:
# 27

# %%
img_gray.max()
# Out:
# 244

# %% [markdown]
# ## Image Resize using Matplotlib & OpenCV P.3

# %%
img=cv2.imread('C:/Users/user/Pictures/123.jpg')
img1= cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img1
# Out:
# array([[[233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230],
#         ...,
#         [233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230]],
#
#        [[233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230],
#         ...,
#         [233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230]],
#
#        [[233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230],
#         ...,
#         [233, 232, 230],
#         [233, 232, 230],
#         [233, 232, 230]],
#
#        ...,
#
#        [[ 97, 136,  21],
#         [ 99, 137,  28],
#         [ 75, 110,  16],
#         ...,
#         [112, 157,  15],
#         [112, 157,  15],
#         [110, 158,  14]],
#
#        [[107, 148,  18],
#         [112, 152,  29],
#         [ 97, 135,  26],
#         ...,
#         [112, 157,  15],
#         [112, 157,  14],
#         [110, 158,  14]],
#
#        [[108, 151,  10],
#         [111, 153,  19],
#         [108, 148,  25],
# ...

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (399, 715, 3)

# %%
new=cv2.resize(img1,(520,420))

# %%
plt.imshow(new)

# %%
new.shape
# Out:
# (420, 520, 3)

# %%
w_change=0.5
h_change =0.5

# %%
new = cv2.resize(img1,(0,0),img1,w_change,h_change)

# %%
plt.imshow(new)

# %%
new.shape
# Out:
# (200, 358, 3)

# %%
img1.shape
# Out:
# (399, 715, 3)
